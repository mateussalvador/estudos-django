# %% [markdown]
# # Usuários
# - Não vamos criar um usuário nesse caso. O próprio django já fornece uma tabela de usuários. Assim, podemos herdar a tabela de usuários de Django e criar a nossa própria.
# - Para isso, usamos `from django.contrib.auth.models import User`. Com isso, já temos a nossa tabela User que vem do próprio Django.
